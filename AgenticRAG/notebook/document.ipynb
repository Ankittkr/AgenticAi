# %%
###Document Structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir=DirectoryLoader(
    path='../data/text_files',
    glob='**/*.txt', ## Pattern to match files 
    loader_cls=TextLoader, ##loader class to use
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
document=dir.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader

dir=DirectoryLoader(
    path='../data/pdf',
    glob='**/*.pdf', ## Pattern to match files 
    loader_cls=PyMuPDFLoader, ##loader class to use
)
pdf_doc=dir.load()
pdf_doc
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-03-10T16:50:42+00:00', 'source': '..\\data\\pdf\\2406049_ANKIT_KUMAR_CSE.pdf', 'file_path': '..\\data\\pdf\\2406049_ANKIT_KUMAR_CSE.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-03-16T20:54:44+00:00', 'trapped': '', 'modDate': 'D:20260316205444Z', 'creationDate': 'D:20260310165042Z', 'page': 0}, page_content='Ankit Kumar\n+91-7367871361\nBachelor of Technology\nankitk.ug24.cs@nitp.ac.in\nComputer Science & Engineering\nlinkedin.com/in/ankittkr21\nNational Institute of Technology, Patna\ngithub.com/Ankittkr\nEducation\nDegree/Certificate\nInstitute/Board\nCGPA/Percentage\nYear\nB.Tech., CSE\nNational Institute of Technology, Patna\n8.56\n2024-Present\nSenior Secondary\nBritish English School, Gaya (CBSE)\n94.6\n2022-2024\nSecondary\nBritish English School, Gaya (CBSE)\n95.8\n2020-2022\nProjects\n• HealthMentor : AI-Powered Symptoms Checker Web App\nByteVerse Hackathon 2025\nTools: HTML, CSS, JavaScript, React\n[§]\n◦Developed a web application to assist users in assessing the severity of their symptoms and locating\ntrustworthy medical professionals nearby.\n◦Utilized artificial intelligence to analyze user-reported symptoms and provide preliminary assessments.\n◦Designed an intuitive UI to ensure ease of navigation and accessibility for users. .\n• PulseTune : Web Music Player\nJun 2025\nTools: HTML, CSS, JavaScript\n[§]\n◦Developed a responsive web-based music player with dynamic playlists and real-time controls.\n◦Implemented custom audio logic including seek bar, volume control, and track navigation. like type,\ncategory, reference, date, and description.\n◦Designed a modern dark-themed UI optimized for desktop and mobile devices.\n◦Managed song data using structured folders and JavaScript DOM manipulation.\n• Secure User Authentication System\nFeb 2026\nTools: Node.js, Express.js, MySQL, JWT, bcrypt\n[§]\n◦Developed a secure RESTful backend API implementing user authentication and authorization using JWT\nwith access tokens and refresh tokens for secure session handling.\n◦Implemented signup and login APIs with bcrypt password hashing and input validation.\n◦Implemented logout and token refresh endpoints with HTTP-only cookies for improved security.\n◦Designed and integrated MySQL database for storing user data and refresh tokens.\nSkills\n• Programming Languages: Python, C++, HTML, JavaScript, JAVA, SQL\n• Coursework: Data Structure & Algorithm, OOPS, DBMS, Operating System, Computer Network\n• Technologies: Django, Express.js, Node.js, Tailwind CSS, ReactJS\n• Tools: Visual Studio Code, POSTMAN, Git, Github\nCODING PROFILE\n• Leetcode\nAchievements\n• Solved 300+ problems @ LeetCode'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-10T12:01:26+00:00', 'source': '..\\data\\pdf\\Resume _ML_Offv1.pdf', 'file_path': '..\\data\\pdf\\Resume _ML_Offv1.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-06-10T12:01:26+00:00', 'trapped': '', 'modDate': 'D:20260610120126Z', 'creationDate': 'D:20260610120126Z', 'page': 0}, page_content='Ankit Kumar\nSoftware Developer\n\x83 +91-7367871361\n# kr.ankitt21@gmail.com\nï linkedin.com/in/ankitkumar\nSummary\nI am a Computer Science student with a strong foundation in programming, data structures along with a growing\ninterest in Machine Learning and Artificial Intelligence. I am seeking a challenging role to my technical skills to\ndevelop intelligent systems and AI-powered applications. I am highly motivated to learn advanced ML/AI concepts,\ncollaborate with teams, and grow in fast-paced, innovation-driven environments.”\nSkills\nProgramming Languages: Python, C++\nMachine Learning: Supervised Learning, Unsupervised Learning, Model Evaluation, Feature Engineering,\nRegression, Classification\nLibraries / Tools: NumPy, Pandas, Matplotlib, Scikit-learn\nData Handling: Data Cleaning, Data Preprocessing, Exploratory Data Analysis (EDA)\nMathematics: Linear Algebra, Probability, Statistics\nTools & Platforms: Jupyter Notebook, Google Colab, Git & GitHub\nCoding Profiles\n• LeetCode: leetcode.com/Ankittkr 21\n• GitHub: GitHub.com/Ankittkr\nProjects\nBanking Risk Analysis – Credit Risk Prediction & Loan Recommendation System\nJun 2026\nTools: Python, Scikit-Learn, NumPy, Pandas, Matplotlib, Streamlit, Kaggle\n[§]\n– Developed a machine learning-based banking analytics platform using Logistic Regression and\nLinear Regression for credit risk classification and loan amount prediction.\n– Built and deployed an interactive Streamlit web application enabling real-time customer risk\nassessment and loan recommendation.\n– Trained and evaluated predictive models on the German Credit Dataset using Scikit-Learn, incorporating\ndata preprocessing, feature engineering, and model validation.\n– Created analytical dashboards with financial data visualizations, risk distribution insights, and\ncustomer profile exploration to support lending decisions.\nAchievements\n• Top 50 Team – Web of Innovation Hackathon 2025: Ranked among top 50 teams for building an innovative web\nsolution (Certificate).\nCertification\n• Coursera – Supervised Machine Learning: Regression and Classification (DeepLearning.AI): Certificate.\nEducation\nB.Tech. in Computer Science Engineering\nExpected Graduation: 2028\nNational Institute of Technology, Patna\nCGPA: 8.56 / 10'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-04-25T08:38:41+00:00', 'source': '..\\data\\pdf\\Resume_OFFv1.pdf', 'file_path': '..\\data\\pdf\\Resume_OFFv1.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-04-25T08:38:41+00:00', 'trapped': '', 'modDate': 'D:20260425083841Z', 'creationDate': 'D:20260425083841Z', 'page': 0}, page_content='Ankit Kumar\nSoftware Developer\n\x83 +91-7367871361\n# kr.ankitt21@gmail.com\nï linkedin.com/in/ankitkumar\nSummary\nI am an aspiring Computer Science student with a strong foundation in programming and web technologies.\nSeeking a challenging role to apply technical skills and contribute to innovative software projects. Motivated to\nlearn, collaborate, and grow in fast-paced development environments.\nSkills\nProgramming Languages: C, C++, Java, JavaScript, Python\nTechnologies: HTML, CSS, React.js, Node.js, Express.js, MongoDB, Tailwind CSS\nTools & Platforms: Git, Postman, VS Code\nCoding Profiles\n• LeetCode: leetcode.com/Ankittkr 21\n• GitHub: GitHub.com/Ankittkr\nExperience\nFrontend Lead – Web Development Cell, NIT Patna\nMarch 2026 – Present\nNational Institute of Technology, Patna\n– Led frontend development for multiple student-driven web projects, ensuring responsive and user-friendly UI/UX design.\n– Collaborated with backend teams to integrate REST APIs using JavaScript and React.js.\n– Standardized UI components and design practices, resulting in consistent and maintainable codebases.\n– Actively contributed to project planning, feature design, and debugging in agile team environments.\nProjects\nPulseTune: Web Music Player\nJun 2025\nTools: HTML, CSS, JavaScript\n[§]\n– Developed a responsive web-based music player with dynamic playlists and real-time controls.\n– Implemented custom audio logic including seek bar, volume control, and track navigation.\n– Included metadata such as type, category, reference, date, and description.\n– Designed a modern dark-themed UI optimized for desktop and mobile devices.\n– Managed song data using structured folders and JavaScript DOM manipulation.\nSecure User Authentication System\nWDC Induction 2026\nTools: Node.js, Express.js, MySQL, JWT, bcrypt\n[§]\n– Developed a secure RESTful backend API implementing user authentication and authorization using JWT\nwith access tokens and refresh tokens for secure session handling.\n– Implemented signup and login APIs with bcrypt password hashing and input validation.\n– Implemented logout and token refresh endpoints with HTTP-only cookies for improved security.\n– Designed and integrated MySQL database for storing user data and refresh tokens.\nAchievements\n• Top 50 Team – Web of Innovation Hackathon 2025: Ranked among top 50 teams for building an innovative web\nsolution (Certificate).\nEducation\nB.Tech. in Computer Science Engineering\nExpected Graduation: 2028\nNational Institute of Technology, Patna\nCGPA: 8.56 / 10'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-07-12T08:29:20+00:00', 'source': '..\\data\\pdf\\Resume_OFFv2.pdf', 'file_path': '..\\data\\pdf\\Resume_OFFv2.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-07-12T08:29:20+00:00', 'trapped': '', 'modDate': 'D:20260712082920Z', 'creationDate': 'D:20260712082920Z', 'page': 0}, page_content='Ankit Kumar\nSoftware Developer\n\x83 +91-7367871361\n# kr.ankitt21@gmail.com\n§ github.com/Ankittkr\nï linkedin.com/in/ankitkumar\nSkills\nProgramming Languages: JavaScript, Python, C++, Java\nFrontend Development: React.js, Redux Toolkit, Tailwind CSS, HTML5, CSS3, Responsive Design, NextJs\nBackend Development: Node.js, Express.js, REST APIs, Authentication, JWT, Middleware, Django\nDatabase: MongoDB, Mongoose, SQL Basics\nTools & Platforms: Git, GitHub, Postman, VS Code, Render, Vercel\nConcepts: Data Structures & Algorithms, OOP, API Integration, System Design Basics\nExperience\nFrontend Lead – Web Development Cell, NIT Patna\nMarch 2026 – Present\nNational Institute of Technology, Patna\n– Led frontend development for multiple student-driven web projects, ensuring responsive and user-friendly UI/UX design.\n– Collaborated with backend teams to integrate REST APIs using JavaScript and Next.js.\n– Standardized UI components and design practices, resulting in consistent and maintainable codebases.\n– Actively contributed to project planning, feature design, and debugging in agile team environments.\nProjects\nSkill Vault – Full Stack Learning Management System\n[§] [\x80]\nReact.js, Redux Toolkit, Node.js, Express.js, MongoDB, Tailwind CSS\n– Engineered a scalable Learning Management System (LMS) with separate student/instructor\nworkflows and Redux Toolkit for centralized state management.\n– Leveraged the Gemini API to build a natural language course recommendation engine that maps user\nintent to relevant course categories.\n– Developed optimized REST APIs with JWT authentication, MongoDB schema modeling, and\nCloudinary for media handling.\n– Built a responsive interface using Tailwind CSS featuring dynamic course filtering, enrollment tracking,\nand instructor dashboards.\nBanking Risk Analysis – Credit Risk Prediction & Loan Recommendation System\n[§] [\x80]\nPython, Scikit-Learn, Pandas, NumPy, Matplotlib, Streamlit\n– Developed a machine learning banking analytics platform using Logistic Regression and Linear\nRegression for credit risk classification and loan amount prediction.\n– Built a Streamlit dashboard with data preprocessing, data visualization, and real-time risk analysis.\n– Applied feature engineering and model evaluation techniques on financial datasets to improve prediction\naccuracy.\nAchievements\n• Rank 8 – Code Enigma 1.1 (Hackslash Club, NIT Patna): Secured Rank 8 in an intra-college competitive\nprogramming contest for exceptional problem-solving skills. (Certificate)\n• Top 50 Team – Web of Innovation Hackathon 2025: Ranked among top 50 teams for building an innovative web\nsolution (Certificate).\n• LeetCode: Solved 500+ coding problems across multiple DSA topics. (Profile)\nCertification\n• Coursera – Supervised Machine Learning: Regression and Classification (DeepLearning.AI): Certificate.\nEducation\nB.Tech. in Computer Science Engineering\nExpected Graduation: 2028\nNational Institute of Technology, Patna\nCGPA: 8.43 / 10')]
